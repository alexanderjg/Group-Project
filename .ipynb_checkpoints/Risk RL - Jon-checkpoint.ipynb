# %%
import numpy as np

# %%
class territory:
    """A territory within Risk"""
    
    def __init__(name, continent, adjacent_nodes):
        self.name = name
        self.continent = continent
        self.adjacents = adjecent_nodes
        self.owner = None
        self.num_units = 0
        return None
        
    def assign_owner(owner, num_units):
        self.owner = owner
        self.num_units = num_units
        return None
    
    def change_units(unit_addition):
        self.num_units += unit_addition
        return self.num_units

# %%
# class world_map:
#     """The full game board within Risk"""
    
#     def __init__()

# %%
class player:
    """A player. This is the base class for the opponents and the agent."""
    
    def __init__(): #Add these later if necessary: num_units=0, num_territories=0, continents_held=None):
        # Initialise all properties
        self.num_units = 0
        self.num_territories = 0
        self.continents = np.array([0, 0, 0])
        self.owned_territories = []
        return None
    
    def change_units(unit_addition):
        """Alter number of units"""
        self.num_units += unit_addition
        return self.num_units
    
    def add_territory(territory_index):
        self.num_territories +=1
        self.owned_territories.append(territory_index)
        return self.num_territories, self.owned_territories

# %%
class world_map:
    """The details of the Risk game board in it's current state"""
    
    def __init__(tot_players, tot_territories):
        self.tot_players = tot_players
        self.players = _make_players()
        
        self.tot_territories = tot_territories
        self.territories = _reset_board()
        
        self.territory_index_lookup = {'Yakutsk':0,'Kamchatka':1,'Siberia':2,'Irkutsk':3,'Japan':4,
                          'Mongolia':5,'Ural':6,'China':7,'Afghanistan':8,'Middle East':9,
                          'India':10,'Siam':11,'Egypt':12,'North Africa':13,'East Africa':14,
                          'Congo':15,'Madagascar':16,'South Africa':17,'Indonesia':18,'New Guinea':19,
                          'Western Australia':20,'Eastern Australia':21}

        self.territory_name_lookup = {v: k for k, v in territory_index_lookup.items()}
        
        self.territory_connections = {0:[1,2,3],1:[0,3,4],2:[0,3,5,6,7],3:[0,1,2,5],4:[1,5],5:[2,3,4,7],6:[2,7,8],7:[2,5,6,8,10,11],8:[6,7,9,10],9:[8,10,12,14],10:[7,8,9,11],11:[7,10,18],12:[9,13,14],13:[12,14,15],14:[9,12,13,15,16,17],15:[13,14,17],16:[14,17],17:[14,15,16],18:[11,19,20],19:[18,20,21],20:[18,19,21],21:[19,20]}
    
    def make_players(tot_players):
        """Initialise each player and put them all into an array"""
    
    def reset_board():
        """Reset the game board and prepare for a new game of Risk"""

        """Things I need:
            Access to the number of players
        Things I want:
            Class properties with number of players/ territories globally"""
        ##############################################
        #### Add all territories to a single list ####
        #### whilst initialising them as classes  ####
        ##############################################
        self.territories_list = []
        for t_index, t_name in territory_index_lookup:
            # Append index (I don't know if this is necessary)
            self.territories_index_list.append(t)

            ## Determine territory properties ##
            # Determine continent
            if t_index <= 11:
                # Territory is in Asia
                continent = 0
            elif t_index <= 17:
                # Territory is in Africa
                continent = 1
            elif t_index <= 21:
                # Territory is in Oceana
                continent = 2
            else:
                raise "Too many territories input"

            # Determine adjacent territories
            #### ALEX PUT YOUR FUNCTION HERE ####
            # adjacent_nodes = 

            self.territories_list.append(territory(t_name, continent, adjacent_nodes))

        ############################################################
        #### Assign units to the territories for the first turn ####
        ############################################################

    def find_connection_names(name):

        connections = territory_connections[territory_index_lookup[name]]

        for i in range(len(connections)):

            connections[i] = territory_name_lookup[connections[i]]

        return connections
